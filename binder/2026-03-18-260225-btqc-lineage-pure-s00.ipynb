# %%
# %load_ext watermark

# %%
import itertools as it
import os

import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from phyloframe import _auxlib as pfa
from phyloframe import legacy as pfl
from pyfonts import load_google_font
import seaborn as sns
from teeplot import teeplot as tp

import pylib
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/alifedata_phyloinformatics_convert/_impl/phytrack_Systematcs.py:7: UserWarning: ImportWarning: phylotrackpy.Systematics import failed; inserting a no-op mock for Systematics. This is likely because phylotrackpy is not installed.
#   warnings.warn(

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2026-04-26T01:41:36.769786+00:00
#
# Python implementation: CPython
# Python version       : 3.11.15
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1044-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# matplotlib: 3.10.0
# pandas    : 2.2.3
# teeplot   : 1.4.2
# pylib     : 0.0.0
# numpy     : 2.1.2
# seaborn   : 0.13.2
# phyloframe: 0.6.1
#
# Watermark: 2.4.3

# %%
teeplot_subdir = os.environ.get(
    "NOTEBOOK_NAME", "2026-03-18-260225-btqc-lineage-pure-s00"
)
teeplot_subdir
# Out:
# '2026-03-18-260225-btqc-lineage-pure-s00'

# %%
pfa.seed_random(1)

# %%
font = load_google_font("Merriweather", weight=300)
mpl.font_manager.fontManager.addfont(font.get_file())
plt.rcParams["font.family"] = font.get_name()

# %% [markdown]
# ## Prep Data

# %%
df_pure = pfl.alifestd_join_roots(
    pd.read_parquet("https://osf.io/qb76y/download"),
)
df_pure
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_join_roots performs update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
#              dstream_data_id          id  ancestor_id  dstream_rank  \
# 0        9223372036854775807           0            0             0
# 1        9223372036854775807           1            0           510
# 2        9223372036854775807           2            1          1022
# 3        9223372036854775807           3            2          1534
# 4        9223372036854775807           4            3          2046
# ...                      ...         ...          ...           ...
# 5321114  9223372036854775807  1884532448   1884532447        151207
# 5321115  9223372036854775807  1884532449   1884532448        151211
# 5321116  9223372036854775807  1884532485   1884532449        151215
# 5321117  9223372036854775807  1884532486   1884532485        151223
# 5321118            999292034  1884532516   1884532486        151225
#
#          hstrat_differentia_bitwidth  dstream_S  \
# 0                                  1         64
# 1                                  1         64
# 2                                  1         64
# 3                                  1         64
# 4                                  1         64
# ...                              ...        ...
# 5321114                            1         64
# 5321115                            1         64
# 5321116                            1         64
# 5321117                            1         64
# 5321118                            1         64
#
#                                          data_hex          genomeFlavor  \
# 0                                            None                   NaN
# 1                                            None                   NaN
# 2                                            None                   NaN
# 3                                            None                   NaN
# 4                                            None                   NaN
# ...                                           ...                   ...
# 5321114                                      None                   NaN
# 5321115                                      None                   NaN
# 5321116                                      None                   NaN
# 5321117                                      None                   NaN
# 5321118  bf7ffeb500024eba02ec8ebce31bafb60049cf3e  genome_purifyingonly
#
#          globalSeed   nCol  ...   layer  layer_T  position  is_root  \
# 0               NaN    NaN  ...     NaN      NaN       NaN     True
# 1               NaN    NaN  ...     NaN      NaN       NaN    False
# 2               NaN    NaN  ...     NaN      NaN       NaN    False
# 3               NaN    NaN  ...     NaN      NaN       NaN    False
# 4               NaN    NaN  ...     NaN      NaN       NaN    False
# ...             ...    ...  ...     ...      ...       ...      ...
# 5321114         NaN    NaN  ...     NaN      NaN       NaN    False
# 5321115         NaN    NaN  ...     NaN      NaN       NaN    False
# 5321116         NaN    NaN  ...     NaN      NaN       NaN    False
# 5321117         NaN    NaN  ...     NaN      NaN       NaN    False
# 5321118         1.0  755.0  ...  1249.0   8761.0  175384.0    False
#
#          num_children  is_leaf is_lineage  is_foliage  extant  is_oldest_root
# 0                   2    False      False       False   False            True
# 1                   2    False      False       False   False           False
# 2                   2    False      False       False   False           False
# 3                   2    False      False       False   False           False
# 4                   2    False      False       False   False           False
# ...               ...      ...        ...         ...     ...             ...
# 5321114             2    False      False       False   False           False
# 5321115             2    False      False       False   False           False
# 5321116             2    False      False       False   False           False
# 5321117             2    False      False       False   False           False
# 5321118             0     True      False        True    True           False
#
# [5321119 rows x 47 columns]

# %%
df_pure = (
    df_pure.pipe(pfl.alifestd_to_working_format)
    .pipe(pfl.alifestd_collapse_unifurcations)
    .pipe(pfl.alifestd_to_working_format)
)
df_pure
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
#              dstream_data_id      id  ancestor_id  dstream_rank  \
# 0        9223372036854775807       0            0             0
# 1        9223372036854775807       1            0           510
# 2        9223372036854775807       2            1          1022
# 3        9223372036854775807       3            2          1534
# 5        9223372036854775807       4            3          3070
# ...                      ...     ...          ...           ...
# 5321082            999231732  102199        99463        151219
# 5321091            999635377  102200       101318        151219
# 5321100            999614266  102201       101776        151222
# 5321110            999190469  102202       101326        151223
# 5321118            999292034  102203       100109        151225
#
#          hstrat_differentia_bitwidth  dstream_S  \
# 0                                  1         64
# 1                                  1         64
# 2                                  1         64
# 3                                  1         64
# 5                                  1         64
# ...                              ...        ...
# 5321082                            1         64
# 5321091                            1         64
# 5321100                            1         64
# 5321110                            1         64
# 5321118                            1         64
#
#                                          data_hex          genomeFlavor  \
# 0                                            None                   NaN
# 1                                            None                   NaN
# 2                                            None                   NaN
# 3                                            None                   NaN
# 5                                            None                   NaN
# ...                                           ...                   ...
# 5321082  bf7ffeb500024eb40a6ceede646f5df60049ce64  genome_purifyingonly
# 5321091  bf7ffeb300024eb40a68af4c65177c810049ce79  genome_purifyingonly
# 5321100  bf7ffeb600024eb70a68af4cb55754010049cec1  genome_purifyingonly
# 5321110  bf7ffeb400024eb8026cae5e0dfb64e60049ceed  genome_purifyingonly
# 5321118  bf7ffeb500024eba02ec8ebce31bafb60049cf3e  genome_purifyingonly
#
#          globalSeed   nCol  ...   layer  layer_T  position  is_root  \
# 0               NaN    NaN  ...     NaN      NaN       NaN     True
# 1               NaN    NaN  ...     NaN      NaN       NaN    False
# 2               NaN    NaN  ...     NaN      NaN       NaN    False
# 3               NaN    NaN  ...     NaN      NaN       NaN    False
# 5               NaN    NaN  ...     NaN      NaN       NaN    False
# ...             ...    ...  ...     ...      ...       ...      ...
# 5321082         1.0  755.0  ...  1249.0   8761.0  115082.0    False
# 5321091         1.0  755.0  ...  1249.0   8761.0  518727.0    False
# 5321100         1.0  755.0  ...  1249.0   8761.0  497616.0    False
# 5321110         1.0  755.0  ...  1249.0   8761.0   73819.0    False
# 5321118         1.0  755.0  ...  1249.0   8761.0  175384.0    False
#
#          num_children  is_leaf is_lineage  is_foliage  extant  is_oldest_root
# 0                   2    False      False       False   False            True
# 1                   2    False      False       False   False           False
# 2                   2    False      False       False   False           False
# 3                   2    False      False       False   False           False
# 5                   2    False      False       False   False           False
# ...               ...      ...        ...         ...     ...             ...
# 5321082             0     True      False        True    True           False
# 5321091             0     True      False        True    True           False
# 5321100             0     True      False        True    True           False
# 5321110             0     True      False        True    True           False
# 5321118             0     True      False        True    True           False
#
# [102204 rows x 47 columns]

# %%
df_pure["x"] = df_pure["position"] // df_pure["nCol"]
df_pure["x_"] = df_pure["x"] / df_pure["nRow"]
df_pure["y"] = df_pure["position"] % df_pure["nCol"]
df_pure["y_"] = df_pure["y"] / df_pure["nCol"]

df_pure["origin_time"] = df_pure["dstream_rank"]

# %%
df_pure_lineage = df_pure.copy()
df_pure_lineage["extant"] = df_pure["is_lineage"]
df_pure_lineage = pfl.alifestd_prune_extinct_lineages_asexual(df_pure_lineage)
df_pure_lineage
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_prune_extinct_lineages_asexual performs delete operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
#           dstream_data_id      id  ancestor_id  dstream_rank  \
# 0     9223372036854775807       0            0             0
# 1     9223372036854775807       1            0           510
# 2     9223372036854775807       2            1          1022
# 3     9223372036854775807      65            2          1534
# 4     9223372036854775807      66           65          2046
# ...                   ...     ...          ...           ...
# 2353  9223372036854775807  102085       102028        150911
# 2354            997600469  102086       102085        150964
# 2355  9223372036854775807  102146       102085        151071
# 2356            998478540  102147       102146        151074
# 2357            999364135  102181       102146        151182
#
#       hstrat_differentia_bitwidth  dstream_S  \
# 0                               1         64
# 1                               1         64
# 2                               1         64
# 3                               1         64
# 4                               1         64
# ...                           ...        ...
# 2353                            1         64
# 2354                            1         64
# 2355                            1         64
# 2356                            1         64
# 2357                            1         64
#
#                                       data_hex          genomeFlavor  \
# 0                                         None                   NaN
# 1                                         None                   NaN
# 2                                         None                   NaN
# 3                                         None                   NaN
# 4                                         None                   NaN
# ...                                        ...                   ...
# 2353                                      None                   NaN
# 2354  bf7ffeb500024db50a6aadc556f3c3b40049ae9b  genome_purifyingonly
# 2355                                      None                   NaN
# 2356  bf7ffeb600024e230a6aadc5b6f3c7f40049bc5c  genome_purifyingonly
# 2357  bf7ffeb500024e8f0a6aadc5a2f3fbf40049c9db  genome_purifyingonly
#
#       globalSeed   nCol  ...  is_leaf  is_lineage  is_foliage  extant  \
# 0            NaN    NaN  ...    False       False       False   False
# 1            NaN    NaN  ...    False       False       False   False
# 2            NaN    NaN  ...    False       False       False   False
# 3            NaN    NaN  ...    False       False       False   False
# 4            NaN    NaN  ...    False       False       False   False
# ...          ...    ...  ...      ...         ...         ...     ...
# 2353         NaN    NaN  ...    False       False       False   False
# 2354         1.0  755.0  ...     True        True       False    True
# 2355         NaN    NaN  ...    False       False       False   False
# 2356         1.0  755.0  ...     True        True       False    True
# 2357         1.0  755.0  ...     True        True       False    True
#
#       is_oldest_root      x        x_      y        y_  origin_time
# 0               True    NaN       NaN    NaN       NaN            0
# 1              False    NaN       NaN    NaN       NaN          510
# 2              False    NaN       NaN    NaN       NaN         1022
# 3              False    NaN       NaN    NaN       NaN         1534
# 4              False    NaN       NaN    NaN       NaN         2046
# ...              ...    ...       ...    ...       ...          ...
# 2353           False    NaN       NaN    NaN       NaN       150911
# 2354           False  331.0  0.282906  614.0  0.813245       150964
# 2355           False    NaN       NaN    NaN       NaN       151071
# 2356           False  324.0  0.276923  620.0  0.821192       151074
# 2357           False  327.0  0.279487  600.0  0.794702       151182
#
# [2358 rows x 52 columns]

# %%
df_pure_with_foliage = df_pure.copy()
df_pure_with_foliage["extant"] = (
    df_pure["is_foliage"] & (np.random.rand(len(df_pure)) < 0.03)
) | df_pure["is_lineage"]
df_pure_with_foliage = pfl.alifestd_prune_extinct_lineages_asexual(
    df_pure_with_foliage
)
df_pure_with_foliage
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_prune_extinct_lineages_asexual performs delete operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
#            dstream_data_id      id  ancestor_id  dstream_rank  \
# 0      9223372036854775807       0            0             0
# 1      9223372036854775807       1            0           510
# 2      9223372036854775807       2            1          1022
# 3      9223372036854775807       3            2          1534
# 4      9223372036854775807       4            3          3070
# ...                    ...     ...          ...           ...
# 18743            999753350  102167        98238        151133
# 18744            999996969  102170        99111        151141
# 18745            999364135  102181       102146        151182
# 18746            999142424  102185       101243        151194
# 18747            999215735  102186       101240        151194
#
#        hstrat_differentia_bitwidth  dstream_S  \
# 0                                1         64
# 1                                1         64
# 2                                1         64
# 3                                1         64
# 4                                1         64
# ...                            ...        ...
# 18743                            1         64
# 18744                            1         64
# 18745                            1         64
# 18746                            1         64
# 18747                            1         64
#
#                                        data_hex          genomeFlavor  \
# 0                                          None                   NaN
# 1                                          None                   NaN
# 2                                          None                   NaN
# 3                                          None                   NaN
# 4                                          None                   NaN
# ...                                         ...                   ...
# 18743  bf7ffeb300024e5e1099334656d82e530049c3a9  genome_purifyingonly
# 18744  bf7ffeb600024e661a59ae3fa3e6f5b70049c4be  genome_purifyingonly
# 18745  bf7ffeb500024e8f0a6aadc5a2f3fbf40049c9db  genome_purifyingonly
# 18746  bf7ffeb500024e9b026caedfc787f9660049cb5e  genome_purifyingonly
# 18747  bf7ffeb400024e9b026cee5e33a31a760049cb44  genome_purifyingonly
#
#        globalSeed   nCol  ...  is_leaf  is_lineage  is_foliage  extant  \
# 0             NaN    NaN  ...    False       False       False   False
# 1             NaN    NaN  ...    False       False       False   False
# 2             NaN    NaN  ...    False       False       False   False
# 3             NaN    NaN  ...    False       False       False   False
# 4             NaN    NaN  ...    False       False       False   False
# ...           ...    ...  ...      ...         ...         ...     ...
# 18743         1.0  755.0  ...     True       False        True    True
# 18744         1.0  755.0  ...     True       False        True    True
# 18745         1.0  755.0  ...     True        True       False    True
# 18746         1.0  755.0  ...     True       False        True    True
# 18747         1.0  755.0  ...     True       False        True    True
#
#        is_oldest_root       x        x_      y        y_  origin_time
# 0                True     NaN       NaN    NaN       NaN            0
# 1               False     NaN       NaN    NaN       NaN          510
# 2               False     NaN       NaN    NaN       NaN         1022
# 3               False     NaN       NaN    NaN       NaN         1534
# 4               False     NaN       NaN    NaN       NaN         3070
# ...               ...     ...       ...    ...       ...          ...
# 18743           False   843.0  0.720513  235.0  0.311258       151133
# 18744           False  1165.0  0.995726  744.0  0.985430       151141
# 18745           False   327.0  0.279487  600.0  0.794702       151182
# 18746           False    34.0  0.029060  104.0  0.137748       151194
# 18747           False   131.0  0.111966  180.0  0.238411       151194
#
# [18748 rows x 52 columns]

# %% [markdown]
# ## Plot Lineage Tree

# %%
for regime, seed in it.product(
    ("pure",),
    range(1),
):
    df = df_pure_lineage.copy()
    df["extant"] = df["origin_time"] > df["origin_time"].max() / 3
    df = (
        df.pipe(pfl.alifestd_prune_extinct_lineages_asexual)
        .pipe(pfl.alifestd_to_working_format)
        .pipe(
            pfl.alifestd_downsample_tips_lineage_asexual,
            criterion_target="layer",
            n_downsample=800,
            seed=seed,
        )
        .pipe(pfl.alifestd_collapse_unifurcations)
        .pipe(pfl.alifestd_delete_unifurcating_roots_asexual)
        .pipe(pfl.alifestd_mark_node_depth_asexual)
    )

    for layout in ("vertical",):
        with tp.teed(
            pylib.chloropleth.draw_ctree,
            df,
            x="x_",
            y="y_",
            cmap=pylib.cmap.bcyr.get_color,
            layout=layout,
            scatter_kws=dict(
                edgecolor="none",
                s=4,
            ),
            scatter_shuffle=1,
            tree_kws=dict(
                edge=dict(
                    color="gainsboro",
                    linewidth=0.5,
                ),
                margins=-0.05,
            ),
            teeplot_outattrs={"regime": regime, "seed": seed},
            teeplot_subdir=teeplot_subdir,
        ) as teed:
            teed.invert_yaxis()
            teed.figure.set_size_inches(3, 1.33)

    ####
    df_ = df_pure_with_foliage.copy()
    df_["x__"] = df_["x_"].copy()
    df_["y__"] = df_["y_"].copy()

    mask = df_["dstream_data_id"].isin(df["dstream_data_id"])
    df_.loc[~mask, "x_"] = pd.NA
    df_.loc[~mask, "y_"] = pd.NA

    for layout, invert in it.product(
        ("vertical",),
        ("y", "xy"),
    ):
        with tp.teed(
            pylib.chloropleth.draw_ctree,
            df_,
            x="x__",
            y="y__",
            cmap=lambda *args, **kwargs: sns.set_hls_values(
                pylib.cmap.bcyr.get_color(*args, **kwargs),
                l=0.9,
                s=0.4,
            ),
            layout=layout,
            scatter_kws=dict(
                edgecolor="none",
                s=4,
            ),
            scatter_shuffle=1,
            tree_kws=dict(
                edge=dict(
                    color="#f4f4f4",
                    linewidth=0.5,
                ),
                margins=-0.05,
            ),
            teeplot_outattrs={
                "invert": invert,
                "regime": f"{regime}-mask",
                "seed": seed,
            },
            teeplot_subdir=teeplot_subdir,
        ) as teed:
            pylib.chloropleth.draw_ctree(
                df_,
                x="x_",
                y="y_",
                cmap=pylib.cmap.bcyr.get_color,
                layout=layout,
                scatter_kws=dict(
                    edgecolor="none",
                    s=4,
                ),
                scatter_shuffle=1,
                tree_kws=dict(
                    edge=dict(
                        alpha=0.0,
                        color="#f4f4f4",
                        linewidth=0.5,
                    ),
                    margins=-0.05,
                ),
            )
            teed.figure.set_size_inches(3, 1.33)
            if "x" in invert:
                teed.invert_xaxis()
            if "y" in invert:
                teed.invert_yaxis()
    ####

    data = df.copy().sort_values(by="node_depth").dropna(subset=["x_", "y_"])
    data = data[data["is_leaf"]].copy()
    data = data.reset_index(drop=True).copy()
    data.index = pd.to_timedelta(data["origin_time"], unit="s")
    data = data.resample("2000s").nearest().copy()
    with tp.teed(
        pylib.chloropleth.draw_cscatter,
        data,
        x="x",
        y="y",
        cmap=pylib.cmap.bcyr.get_color,
        despine=True,
        major=100,
        minor=None,
        xmax=1170,
        ymax=755,
        scatter_kws=dict(
            alpha=0.7,
            color="none",
            edgecolor="white",
            linewidth=1,
            linestyle="-",
            marker="o",
            s=10,
            zorder=120,
        ),
        teeplot_outattrs={
            "cmap": "bcyr",
            "regime": regime,
            "seed": seed,
        },
        teeplot_subdir=teeplot_subdir,
    ) as teed:
        for i in range(len(data)):
            teed.plot(
                data["x"][i:],
                data["y"][i:],
                alpha=1 / len(data),
                color="black",
                lw=6,
            )
        teed.plot(
            data["x"],
            data["y"],
            alpha=0.2,
            color="black",
            lw=6,
            zorder=150,
        )
        teed.set_xlabel(None)
        teed.set_ylabel(None)
        teed.set_aspect("equal")
        fig = teed.figure
        fig.set_size_inches(3, 2)
        fig.tight_layout()
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_prune_extinct_lineages_asexual performs delete operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_downsample_tips_lineage_asexual performs delete operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_prune_extinct_lineages_asexual performs delete operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_delete_unifurcating_roots_asexual performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children', 'node_depth']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/layout=vertical+regime=pure+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/layout=vertical+regime=pure+seed=0+viz=draw-ctree+x=x+y=y+ext=.png
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/invert=y+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/invert=y+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.png
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/invert=xy+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/invert=xy+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.png
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/cmap=bcyr+regime=pure+seed=0+viz=draw-cscatter+x=x+y=y+ext=.pdf
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/cmap=bcyr+regime=pure+seed=0+viz=draw-cscatter+x=x+y=y+ext=.png

# %% [markdown]
# ## Combined Plots

# %%
with tp.teed(
    plt.subplots,
    ncols=1,
    nrows=2,
    figsize=(3, 4),
    gridspec_kw={"height_ratios": [2, 1], "hspace": 0.1, "wspace": 0.05},
    teeplot_subdir=teeplot_subdir,
) as fig:
    fig, axs = fig

    for regime in ("pure",):
        pylib.chloropleth.draw_cscatter(
            data,
            x="x",
            y="y",
            ax=axs[0],
            cmap=pylib.cmap.bcyr.get_color,
            despine=True,
            major=100,
            minor=None,
            xmax=1170,
            ymax=755,
            scatter_kws=dict(
                alpha=0.7,
                color="none",
                edgecolor="white",
                linewidth=1,
                linestyle="-",
                marker="o",
                s=10,
                zorder=120,
            ),
        )
        for i in range(len(data)):
            axs[0].plot(
                data["x"][i:],
                data["y"][i:],
                alpha=1 / len(data),
                color="black",
                lw=6,
            )
        axs[0].plot(
            data["x"],
            data["y"],
            alpha=0.2,
            color="black",
            lw=6,
            zorder=150,
        )
        axs[0].set_xlabel(None)
        axs[0].set_ylabel(None)
        axs[0].set_aspect("equal", anchor="S")

        pylib.chloropleth.draw_ctree(
            df_,
            x="x__",
            y="y__",
            ax=axs[1],
            cmap=lambda *args, **kwargs: sns.set_hls_values(
                pylib.cmap.bcyr.get_color(*args, **kwargs),
                l=0.9,
                s=0.4,
            ),
            layout=layout,
            scatter_kws=dict(
                edgecolor="none",
                s=4,
            ),
            scatter_shuffle=1,
            tree_kws=dict(
                edge=dict(
                    color="#f4f4f4",
                    linewidth=0.5,
                ),
                margins=-0.05,
            ),
        )
        pylib.chloropleth.draw_ctree(
            df_,
            x="x_",
            y="y_",
            ax=axs[1],
            cmap=pylib.cmap.bcyr.get_color,
            layout=layout,
            scatter_kws=dict(
                edgecolor="none",
                s=4,
            ),
            scatter_shuffle=1,
            tree_kws=dict(
                edge=dict(
                    alpha=0.0,
                    color="#f4f4f4",
                    linewidth=0.5,
                ),
                margins=-0.05,
            ),
        )
        axs[1].invert_xaxis()
        axs[1].invert_yaxis()
        axs[1].set_anchor("N")
# Out:
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/phyloframe/legacy/_alifestd_warn_topological_sensitivity.py:35: UserWarning: alifestd_collapse_unifurcations performs delete/update operations that do not update topology-dependent columns, which may be invalidated: ['num_children']. Use `origin_time` to recalculate branch lengths for collapsed phylogeny. To silence this warning, use alifestd_drop_topological_sensitivity{_polars} or set HSTRAT_ALIFESTD_WARN_TOPOLOGICAL_SENSITIVITY_SUPPRESS environment variable.
#   warnings.warn(
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/viz=subplots+ext=.pdf
# teeplots/2026-03-18-260225-btqc-lineage-pure-s00/viz=subplots+ext=.png

# %%
import pymupdf

spatial_positions_path = (
    "assets/2026-03-04-wse-spatial-phylo-singleton-positions.pdf"
)
spatial_template_path = (
    "assets/2026-03-04-wse-spatial-phylo-singleton-template.pdf"
)

spatial_positions_doc = pymupdf.open(spatial_positions_path)
print(
    f"Positions: {len(spatial_positions_doc)} page(s), size {spatial_positions_doc[0].rect}"
)

spatial_template_doc = pymupdf.open(spatial_template_path)
print(
    f"Template:  {len(spatial_template_doc)} page(s), size {spatial_template_doc[0].rect}"
)
# Out:
# Positions: 1 page(s), size Rect(0.0, 0.0, 413.5670471191406, 279.6712341308594)
# Template:  1 page(s), size Rect(0.0, 0.0, 413.5670471191406, 279.6712341308594)

# %%
spatial_target_colors = {
    # "accede": "#ACCEDE",
    "beefed": "#BEEFED",
    # "decade": "#DECADE",
    "deadbe": "#DEADBE",
}


def hex_to_rgb_float(hex_color):
    h = hex_color.lstrip("#")
    return tuple(int(h[i : i + 2], 16) / 255.0 for i in (0, 2, 4))


def find_rects_by_color(page, hex_color, tol=2 / 255):
    target = hex_to_rgb_float(hex_color)
    rects = []
    for path in page.get_drawings():
        fill = path.get("fill")
        if fill is None or len(fill) != 3:
            continue
        if all(abs(fill[i] - target[i]) < tol for i in range(3)):
            rects.append(path["rect"])
    return rects


spatial_positions_page = spatial_positions_doc[0]
spatial_color_rects = {}
for name, hex_color in spatial_target_colors.items():
    rects = find_rects_by_color(spatial_positions_page, hex_color)
    spatial_color_rects[name] = rects
    for r in rects:
        print(f"  {name} ({hex_color}): {r}")

spatial_positions_doc.close()
# Out:
#   beefed (#BEEFED): Rect(161.38299560546875, 23.645000457763672, 382.25, 169.08599853515625)
#   deadbe (#DEADBE): Rect(161.87899780273438, 168.78900146484375, 382.7460021972656, 279.6719970703125)

# %%
spatial_plot_paths = {
    # "accede": "cmap=bcyr+regime=pure+seed=0+viz=draw-cscatter+x=x+y=y+ext=.pdf",
    "beefed": "cmap=bcyr+regime=pure+seed=0+viz=draw-cscatter+x=x+y=y+ext=.pdf",
    # "decade": "layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf",
    "deadbe": "invert=xy+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf",
}

spatial_plot_docs = {}
for name, filename in spatial_plot_paths.items():
    path = os.path.join("teeplots", teeplot_subdir, filename)
    print(f"Loading {name} from: {path}")
    spatial_plot_docs[name] = pymupdf.open(path)

page = spatial_template_doc[0]
for name, rects in spatial_color_rects.items():
    src_doc = spatial_plot_docs[name]
    delta = {
        "accede": 11,
        "beefed": 11,
        "decade": 5,
        "deadbe": 5,
    }[name]
    for rect in rects:
        rect.y0 -= delta + 7 * name.startswith("de")
        rect.x0 -= delta
        rect.y1 += delta - 7 * name.startswith("de")
        rect.x1 += delta
        page.show_pdf_page(rect, src_doc, 0)
        print(f"  Inserted {name} at {rect}")

# set Interpolate on all raster images so PDF viewers use smooth scaling
for img in page.get_images(full=True):
    xref = img[0]
    if "/Interpolate" not in spatial_template_doc.xref_object(xref):
        spatial_template_doc.xref_set_key(xref, "Interpolate", "true")

spatial_output_destination = f"teeplots/{teeplot_subdir}/"
os.makedirs(spatial_output_destination, exist_ok=True)
spatial_output_path = os.path.join(
    spatial_output_destination,
    "wse-spatial-singleton-phylo-filled.pdf",
)
spatial_template_doc.save(spatial_output_path, garbage=4, deflate=True)
spatial_template_doc.close()
for d in spatial_plot_docs.values():
    d.close()
print(f"\nSaved to {spatial_output_path}")
# Out:
# Loading beefed from: teeplots/2026-03-18-260225-btqc-lineage-pure-s00/cmap=bcyr+regime=pure+seed=0+viz=draw-cscatter+x=x+y=y+ext=.pdf
# Loading deadbe from: teeplots/2026-03-18-260225-btqc-lineage-pure-s00/invert=xy+layout=vertical+regime=pure-mask+seed=0+viz=draw-ctree+x=x+y=y+ext=.pdf
#   Inserted beefed at Rect(150.38299560546875, 12.645000457763672, 393.25, 180.08599853515625)
#   Inserted deadbe at Rect(156.87899780273438, 156.78900146484375, 387.7460021972656, 277.6719970703125)
#
# Saved to teeplots/2026-03-18-260225-btqc-lineage-pure-s00/wse-spatial-singleton-phylo-filled.pdf

# %%
spatial_filled_doc = pymupdf.open(spatial_output_path)
dpi = 600
mat = pymupdf.Matrix(dpi / 72, dpi / 72)
pix = spatial_filled_doc[0].get_pixmap(matrix=mat, alpha=False)
spatial_png_path = spatial_output_path.replace(".pdf", ".png")
pix.save(spatial_png_path)
spatial_filled_doc.close()
print(f"Saved {pix.width}x{pix.height} @ {dpi} DPI to {spatial_png_path}")
# Out:
# Saved 3447x2331 @ 600 DPI to teeplots/2026-03-18-260225-btqc-lineage-pure-s00/wse-spatial-singleton-phylo-filled.png
