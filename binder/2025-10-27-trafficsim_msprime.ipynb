# %%
# %load_ext watermark

# %%
import os

from IPython.display import display
import pandas as pd

import pylib  # noqa: F401

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2026-02-22T03:28:44.343886+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1044-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# pylib : 0.0.0
# pandas: 2.2.3
#
# Watermark: 2.4.3

# %%
teeplot_subdir = os.environ.get("2025-10-27-trafficsim_msprime", None)
teeplot_subdir

# %% [markdown]
# ## Prep Data

# %%
df_traffic = pd.read_parquet("https://osf.io/download/7jv4d/")
display(df_traffic.describe()), display(df_traffic.head()), display(
    df_traffic.tail()
);
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#          population  migration_count    grid_dim  num_alleles   num_demes  \
# count  6.277950e+07     6.277950e+07  62779500.0   62779500.0  62779500.0
# mean   4.495000e+02     2.345244e+03        30.0        512.0       900.0
# std    2.598075e+02     3.905598e+02         0.0          0.0         0.0
# min    0.000000e+00     7.620000e+02        30.0        512.0       900.0
# 25%    2.247500e+02     2.056000e+03        30.0        512.0       900.0
# 50%    4.495000e+02     2.342000e+03        30.0        512.0       900.0
# 75%    6.742500e+02     2.627000e+03        30.0        512.0       900.0
# max    8.990000e+02     4.895000e+03        30.0        512.0       900.0
#
#         deme_size  migration_rate      ploidy   random_seed  \
# count  62779500.0    6.277950e+07  62779500.0  6.277950e+07
# mean        512.0    5.000000e-02         1.0  4.998530e+03
# std           0.0    6.897261e-15         0.0  2.885078e+03
# min         512.0    5.000000e-02         1.0  1.000000e+00
# 25%         512.0    5.000000e-02         1.0  2.499000e+03
# 50%         512.0    5.000000e-02         1.0  4.997000e+03
# 75%         512.0    5.000000e-02         1.0  7.498000e+03
# max         512.0    5.000000e-02         1.0  1.000000e+04
#
#        slurm_array_task_id  time_thresh
# count         6.277950e+07   62779500.0
# mean          4.997530e+03          inf
# std           2.885078e+03          NaN
# min           0.000000e+00      30000.0
# 25%           2.498000e+03      50000.0
# 50%           4.996000e+03     300000.0
# 75%           7.497000e+03    1000000.0
# max           9.999000e+03          inf
#    population  migration_count  grid_dim  num_alleles  num_demes  deme_size  \
# 0         433             2187        30          512        900        512
# 1         307             2173        30          512        900        512
# 2         434             2167        30          512        900        512
# 3         835             2166        30          512        900        512
# 4         404             2144        30          512        900        512
#
#    migration_rate  ploidy  random_seed  slurm_array_task_id  time_thresh
# 0            0.05       1            1                    0      30000.0
# 1            0.05       1            1                    0      30000.0
# 2            0.05       1            1                    0      30000.0
# 3            0.05       1            1                    0      30000.0
# 4            0.05       1            1                    0      30000.0
#           population  migration_count  grid_dim  num_alleles  num_demes  \
# 62779495         360             1941        30          512        900
# 62779496         870             1431        30          512        900
# 62779497         899             1414        30          512        900
# 62779498           0             1385        30          512        900
# 62779499          29             1262        30          512        900
#
#           deme_size  migration_rate  ploidy  random_seed  slurm_array_task_id  \
# 62779495        512            0.05       1           10                    9
# 62779496        512            0.05       1           10                    9
# 62779497        512            0.05       1           10                    9
# 62779498        512            0.05       1           10                    9
# 62779499        512            0.05       1           10                    9
#
#           time_thresh
# 62779495          inf
# 62779496          inf
# 62779497          inf
# 62779498          inf
# 62779499          inf

# %%
df_duration = pd.read_parquet("https://osf.io/download/hrq6a/")
display(df_duration.describe()), display(df_duration.head()), display(
    df_duration.tail()
);
# Out:
#          population   origin_time   grid_dim  num_alleles  num_demes  \
# count  8.968500e+06  8.968500e+06  8968500.0    8968500.0  8968500.0
# mean   4.495000e+02  9.263131e+05       30.0        512.0      900.0
# std    2.598075e+02  4.995791e+05        0.0          0.0        0.0
# min    0.000000e+00  1.202029e+05       30.0        512.0      900.0
# 25%    2.247500e+02  5.735996e+05       30.0        512.0      900.0
# 50%    4.495000e+02  8.012084e+05       30.0        512.0      900.0
# 75%    6.742500e+02  1.150903e+06       30.0        512.0      900.0
# max    8.990000e+02  4.169518e+06       30.0        512.0      900.0
#
#        deme_size  migration_rate     ploidy   random_seed  slurm_array_task_id
# count  8968500.0    8.968500e+06  8968500.0  8.968500e+06         8.968500e+06
# mean       512.0    5.000000e-02        1.0  4.998530e+03         4.997530e+03
# std          0.0    8.951174e-16        0.0  2.885078e+03         2.885078e+03
# min        512.0    5.000000e-02        1.0  1.000000e+00         0.000000e+00
# 25%        512.0    5.000000e-02        1.0  2.499000e+03         2.498000e+03
# 50%        512.0    5.000000e-02        1.0  4.997000e+03         4.996000e+03
# 75%        512.0    5.000000e-02        1.0  7.498000e+03         7.497000e+03
# max        512.0    5.000000e-02        1.0  1.000000e+04         9.999000e+03
#    population   origin_time  grid_dim  num_alleles  num_demes  deme_size  \
# 0           0  1.067435e+06        30          512        900        512
# 1           1  1.067425e+06        30          512        900        512
# 2           2  1.092280e+06        30          512        900        512
# 3           3  1.092293e+06        30          512        900        512
# 4           4  1.065254e+06        30          512        900        512
#
#    migration_rate  ploidy  random_seed  slurm_array_task_id
# 0            0.05       1            1                    0
# 1            0.05       1            1                    0
# 2            0.05       1            1                    0
# 3            0.05       1            1                    0
# 4            0.05       1            1                    0
#          population    origin_time  grid_dim  num_alleles  num_demes  \
# 8968495         895  687200.542495        30          512        900
# 8968496         896  687228.729809        30          512        900
# 8968497         897  687214.052359        30          512        900
# 8968498         898  642508.366192        30          512        900
# 8968499         899  680029.280832        30          512        900
#
#          deme_size  migration_rate  ploidy  random_seed  slurm_array_task_id
# 8968495        512            0.05       1           10                    9
# 8968496        512            0.05       1           10                    9
# 8968497        512            0.05       1           10                    9
# 8968498        512            0.05       1           10                    9
# 8968499        512            0.05       1           10                    9

# %%
df_traffic.groupby(["num_demes", "time_thresh"])["migration_count"].max()
# Out:
# num_demes  time_thresh
# 900        30000.0        2419
#            50000.0        2560
#            100000.0       2785
#            300000.0       3117
#            500000.0       3279
#            1000000.0      3674
#            inf            4895
# Name: migration_count, dtype: int64

# %%
df_traffic.groupby(["num_demes", "time_thresh"])["migration_count"].mean()
# Out:
# num_demes  time_thresh
# 900        30000.0        1920.638888
#            50000.0        2024.801611
#            100000.0       2168.102115
#            300000.0       2403.926859
#            500000.0       2518.949021
#            1000000.0      2654.797407
#            inf            2725.492275
# Name: migration_count, dtype: float64

# %%
df_duration.groupby("num_demes")["origin_time"].max()
# Out:
# num_demes
# 900    4.169518e+06
# Name: origin_time, dtype: float64
